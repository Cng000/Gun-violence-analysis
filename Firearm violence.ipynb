# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.max_rows = 999
pd.options.display.max_columns =24
import datetime as dt
import colorsys

from bokeh.models.tools import HoverTool

# %%
df = pd.read_csv("/Users/dekuwinekogda/Desktop/Datascience/Gun-violence-analysis/dataset/Index__Violent__Property__and_Firearm_Rates_By_County__Beginning_1990.csv", encoding = "ISO-8859-1")

# %%
df
# Out:
#             County  Year    Population  Index Count  Index Rate  \
# 0           Albany  1990  2.925940e+05        14418      4927.6
# 1         Allegany  1990  5.047000e+04         1280      2536.2
# 2            Bronx  1990  1.200900e+06       104729      8720.9
# 3           Broome  1990  2.121600e+05         7480      3525.6
# 4      Cattaraugus  1990  8.423400e+04         2578      3060.5
# 5           Cayuga  1990  8.231300e+04         2331      2831.9
# 6       Chautauqua  1990  1.418950e+05         5713      4026.2
# 7          Chemung  1990  9.519500e+04         3816      4008.6
# 8         Chenango  1990  5.176800e+04         1178      2275.5
# 9          Clinton  1990  8.596900e+04         2221      2583.5
# 10        Columbia  1990  6.298200e+04         1954      3102.5
# 11        Cortland  1990  4.896300e+04         2123      4335.9
# 12        Delaware  1990  4.722500e+04         1092      2312.3
# 13        Dutchess  1990  2.594620e+05         8957      3452.1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1736 entries, 0 to 1735
# Data columns (total 11 columns):
# County            1736 non-null object
# Year              1736 non-null int64
# Population        1736 non-null float64
# Index Count       1736 non-null int64
# Index Rate        1736 non-null float64
# Violent Count     1736 non-null int64
# Violent Rate      1736 non-null float64
# Property Count    1736 non-null int64
# Property Rate     1736 non-null float64
# Firearm Count     1661 non-null float64
# Firearm Rate      1661 non-null float64
# dtypes: float64(6), int64(4), object(1)
# memory usage: 149.3+ KB

# %%
df.shape
# Out:
# (1736, 11)

# %%
df.describe()
# Out:
#               Year    Population    Index Count    Index Rate  Violent Count  \
# count  1736.000000  1.736000e+03    1736.000000   1736.000000    1736.000000
# mean   2003.500000  3.058618e+05    9886.133065   2516.591993    1777.838710
# std       8.080075  5.164584e+05   22336.251957   1213.934260    5609.335735
# min    1990.000000  4.505000e+03      36.000000    386.600000       1.000000
# 25%    1996.750000  5.176575e+04    1084.000000   1758.225000      91.000000
# 50%    2003.500000  9.086400e+04    2093.000000   2289.150000     177.500000
# 75%    2010.250000  2.353158e+05    6593.500000   2942.200000     681.750000
# max    2017.000000  2.646816e+06  217786.000000  14651.100000   63087.000000
#
#        Violent Rate  Property Count  Property Rate  Firearm Count  \
# count   1736.000000     1736.000000    1736.000000    1661.000000
# mean     284.058295     8101.416475    2232.129378     303.053582
# std      300.254786    17154.770214    1004.868994    1528.577826
# ...

# %%
df_duplicates = df.drop_duplicates()
df_duplicates.shape
# Out:
# (1736, 11)

# %%
null_columns=df.columns[df.isnull().any()]
df[null_columns].isnull().sum()
# Out:
# Firearm Count    75
# Firearm Rate     75
# dtype: int64

# %%
df.fillna(0,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1736 entries, 0 to 1735
# Data columns (total 11 columns):
# County            1736 non-null object
# Year              1736 non-null int64
# Population        1736 non-null float64
# Index Count       1736 non-null int64
# Index Rate        1736 non-null float64
# Violent Count     1736 non-null int64
# Violent Rate      1736 non-null float64
# Property Count    1736 non-null int64
# Property Rate     1736 non-null float64
# Firearm Count     1736 non-null float64
# Firearm Rate      1736 non-null float64
# dtypes: float64(6), int64(4), object(1)
# memory usage: 149.3+ KB

# %%
ds=df.groupby(['Year','County'])["Violent Count", "Firearm Count", "Population"].apply(lambda x : x.astype(int).sum())

# %%
ds.head(25).plot()

# %%
ds.head(5)
# Out:
#                   Violent Count  Firearm Count  Population
# Year County
# 1990 Albany                1524            122      292594
#      Allegany               146              1       50470
#      Bronx                33635          10869     1200900
#      Broome                 306             13      212160
#      Cattaraugus            171              5       84234

# %%
series = df['Year'].value_counts()[:63]
series
# Out:
# 2017    62
# 2016    62
# 1991    62
# 1992    62
# 1993    62
# 1994    62
# 1995    62
# 1996    62
# 1997    62
# 1998    62
# 1999    62
# 2000    62
# 2001    62
# 2002    62
# 2003    62
# 2004    62
# 2005    62
# 2006    62
# 2007    62
# 2008    62
# 2009    62
# 2010    62
# 2011    62
# 2012    62
# 2013    62
# 2014    62
# 2015    62
# 1990    62
# Name: Year, dtype: int64

# %%
 ds.groupby('County')['Violent Count'].sum()['Albany']
# Out:
# 38615

# %%
ds0 = ds.groupby('County')['Violent Count','Firearm Count', "Population"].sum()
ds0.head(5)
# Out:
#              Violent Count  Firearm Count  Population
# County
# Albany               38615           4540     8363084
# Allegany              2916            147     1400407
# Bronx               489788          72870    36982432
# Broome               12876           1188     5647942
# Cattaraugus           5489            354     2289904

# %%
ds0.plot(kind='bar', figsize=(30,15),fontsize=22)

# %%
ds1 = ds.groupby('County')['Violent Count','Firearm Count'].sum()
ds1.head(5)
# Out:
#              Violent Count  Firearm Count
# County
# Albany               38615           4540
# Allegany              2916            147
# Bronx               489788          72870
# Broome               12876           1188
# Cattaraugus           5489            354

# %%
ds1.plot(kind='bar', figsize=(30,15),fontsize=22)

# %%
ds2 = ds.groupby('County')['Violent Count'].sum()
ds2.head(5)
# Out:
# County
# Albany          38615
# Allegany         2916
# Bronx          489788
# Broome          12876
# Cattaraugus      5489
# Name: Violent Count, dtype: int64

# %%
ds2.plot(kind='bar', figsize=(30,15),fontsize=22)

# %%
ds3 = ds.groupby('County')['Firearm Count'].sum()
ds3.head(63)
# Out:
# County
# Albany            4540
# Allegany           147
# Bronx            72870
# Broome            1188
# Cattaraugus        354
# Cayuga             325
# Chautauqua         931
# Chemung            627
# Chenango           126
# Clinton            123
# Columbia           325
# Cortland           116
# Delaware           196
# Dutchess          3091
# Erie             32918
# Essex              104
# Franklin           149
# Fulton             292
# Genesee            225
# Greene             144
# Hamilton             7
# Herkimer           187
# Jefferson          423
# Kings           143340
# Lewis               73
# Livingston         169
# Madison            128
# Monroe           25980
# Montgomery         125
# Nassau           14193
# New York         66225
# Niagara           3398
# Oneida            2725
# Onondaga          7826
# Ontario            283
# Orange            3510
# Orleans            142
# Oswego             307
# Otsego             228
# ...

# %%
# hover = HoverTool()
# hover.tooltips = [
#     ("Totals", "@TONS_HE High Explosive / @TONS_IC Incendiary / @TONS_FRAG Fragmentation")]

# hover.mode = 'vline'

# p.add_tools(hover)

# show(p)

# %%
ds3.plot(kind='bar', figsize=(30,15),fontsize=22)

# %%
ds4 = ds.groupby('County')['Population'].sum()
ds4.head(5)
ds4.plot(kind='bar', figsize=(30,15),fontsize=22)

# %%
s = df.loc[df['County'].isin(['Albany', 'Allegany', 'Bronx', 'Broome', 'Cattaraugus', 'Cayuga', 'Chautauqua', 'Chemung', 'Chenango', 'Clinton', 'Columbia', 'Cortland', 'Delaware', 'Dutchess', 'Erie', 'Essex', 'Franklin', 'Fulton', 'Genesee', 'Greene', 'Hamilton', 'Herkimer', 'Jefferson', 'Kings', 'Lewis', 'Livingston', 'Madison', 'Monroe', 'Montgomery', 'Nassau', 'New York', 'Niagara', 'Oneida', 'Onondaga', 'Ontario', 'Orange', 'Orleans', 'Oswego', 'Otsego', 'Putnam', 'Queens', 'Rensselaer', 'Richmond', 'Rockland', 'Saratoga', 'Schenectady', 'Schoharie', 'Schuyler', 'Seneca', 'St Lawrence', 'St. Lawrence', 'Steuben', 'Suffolk', 'Sullivan', 'Tioga', 'Tompkins', 'Ulster', 'Warren', 'Washington', 'Wayne', 'Westchester', 'Wyoming', 'Yates']), ['Violent Count','Firearm Count','Population']].sum()
s
# Out:
# Violent Count    3.086328e+06
# Firearm Count    5.033720e+05
# Population       5.309760e+08
# dtype: float64

# %%
s1 = df.loc[df['County'].isin(['Albany', 'Allegany', 'Bronx', 'Broome', 'Cattaraugus', 'Cayuga', 'Chautauqua', 'Chemung', 'Chenango', 'Clinton', 'Columbia', 'Cortland', 'Delaware', 'Dutchess', 'Erie', 'Essex', 'Franklin', 'Fulton', 'Genesee', 'Greene', 'Hamilton', 'Herkimer', 'Jefferson', 'Kings', 'Lewis', 'Livingston', 'Madison', 'Monroe', 'Montgomery', 'Nassau', 'New York', 'Niagara', 'Oneida', 'Onondaga', 'Ontario', 'Orange', 'Orleans', 'Oswego', 'Otsego', 'Putnam', 'Queens', 'Rensselaer', 'Richmond', 'Rockland', 'Saratoga', 'Schenectady', 'Schoharie', 'Schuyler', 'Seneca', 'St Lawrence', 'St. Lawrence', 'Steuben', 'Suffolk', 'Sullivan', 'Tioga', 'Tompkins', 'Ulster', 'Warren', 'Washington', 'Wayne', 'Westchester', 'Wyoming', 'Yates']), ['Violent Count']].sum()
s1
# Out:
# Violent Count    3086328
# dtype: int64

# %%
s = df.loc[df['County'].isin(['Allegany']), ['Violent Count']].sum()/s1


s
# Out:
# Violent Count    0.000945
# dtype: float64
